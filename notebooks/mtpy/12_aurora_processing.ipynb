# %% [markdown]
# # Processing workflow with MTpy-v2
#
# Now that we have seen to make MTH5 files and use Aurora, we can use a slightly different workflow using `mtpy-v2`.

# %%
import warnings
from pathlib import Path
from loguru import logger
import pandas as pd

from mtpy.processing import AuroraProcessing

warnings.filterwarnings("ignore")

# %%
survey_dir = Path(r"c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5")

edi_path = survey_dir.parent.joinpath("EDI_Files_aurora")
edi_path.mkdir(exist_ok=True)

# Or try the alternative band file
band_file = Path().cwd().parent.parent.joinpath("data", "transfer_functions", "bs_eight_level.cfg")

band_file_24k = Path(r"C:\Users\jpeacock\OneDrive - DOI\Documents\GitHub\iris-mt-course-2022\data\transfer_functions\phx_24k_bs.txt")

# this is how the different transfer functions will be merged.
merge_dict = {
    150: {"period_min": 1.0 / 30, "period_max": 10000},
    24000: {"period_min": 1.0 / 8000, "period_max": 1.0 / 31},
}

# %%
ap = AuroraProcessing(merge_dictionary=merge_dict)

ap.local_mth5_path = survey_dir.joinpath("phx_9043.h5")
ap.remote_mth5_path = survey_dir.joinpath("phx_1003.h5")

ap.local_station_id = "9043"
ap.remote_station_id = "1003"

ap.run_summary = ap.get_run_summary()
# Out:
# 2024-11-08T14:18:27.958028-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:18:30.491775-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_1003.h5

# %%
ap.run_summary.mini_summary
# Out:
#    survey station         run                     start  \
# 0    MIST    9043  sr150_0001 2024-03-28 14:45:58+00:00
# 1    MIST    9043  sr24k_0001 2024-03-28 21:46:42+00:00
# 2    MIST    9043  sr24k_0002 2024-03-28 22:40:42+00:00
# 3    MIST    9043  sr24k_0003 2024-03-28 23:34:42+00:00
# 4    MIST    9043  sr24k_0004 2024-03-29 00:28:42+00:00
# 5    MIST    9043  sr24k_0005 2024-03-29 01:22:42+00:00
# 6    MIST    9043  sr24k_0006 2024-03-29 02:16:42+00:00
# 7    MIST    9043  sr24k_0007 2024-03-29 03:10:42+00:00
# 8    MIST    9043  sr24k_0008 2024-03-29 04:04:42+00:00
# 9    MIST    9043  sr24k_0009 2024-03-29 04:58:42+00:00
# 10   MIST    9043  sr24k_0010 2024-03-29 05:52:42+00:00
# 11   MIST    9043  sr24k_0011 2024-03-29 06:46:42+00:00
# 12   MIST    9043  sr24k_0012 2024-03-29 07:40:42+00:00
# 13   MIST    9043  sr24k_0013 2024-03-29 08:34:42+00:00
# 14   MIST    9043  sr24k_0014 2024-03-29 09:28:42+00:00
# 15   MIST    9043  sr24k_0015 2024-03-29 10:22:42+00:00
# 16   MIST    9043  sr24k_0016 2024-03-29 11:16:42+00:00
# 17   MIST    9043  sr24k_0017 2024-03-29 12:10:42+00:00
# 18   MIST    9043  sr24k_0018 2024-03-29 13:04:42+00:00
# 19   MIST    9043  sr24k_0019 2024-03-29 13:58:42+00:00
# 20   MIST    9043  sr24k_0020 2024-03-29 14:52:42+00:00
# 21   MIST    9043  sr24k_0021 2024-03-29 15:46:42+00:00
# 22   MIST    9043  sr24k_0022 2024-03-29 16:40:42+00:00
# 23   MIST    1003  sr150_0001 2024-03-27 13:51:05+00:00
#
#                                    end       duration
# 0  2024-03-29 10:04:39.993333333+00:00   69521.993333
# 1  2024-03-28 21:46:42.999958333+00:00       0.999958
# 2  2024-03-28 22:40:42.999958333+00:00       0.999958
# 3  2024-03-28 23:34:42.999958333+00:00       0.999958
# 4  2024-03-29 00:28:42.999958333+00:00       0.999958
# 5  2024-03-29 01:22:42.999958333+00:00       0.999958
# 6  2024-03-29 02:16:42.999958333+00:00       0.999958
# 7  2024-03-29 03:10:42.999958333+00:00       0.999958
# 8  2024-03-29 04:04:42.999958333+00:00       0.999958
# 9  2024-03-29 04:58:42.999958333+00:00       0.999958
# 10 2024-03-29 05:52:42.999958333+00:00       0.999958
# 11 2024-03-29 06:46:42.999958333+00:00       0.999958
# 12 2024-03-29 07:40:42.999958333+00:00       0.999958
# 13 2024-03-29 08:34:42.999958333+00:00       0.999958
# 14 2024-03-29 09:28:42.999958333+00:00       0.999958
# 15 2024-03-29 10:22:42.999958333+00:00       0.999958
# 16 2024-03-29 11:16:42.999958333+00:00       0.999958
# 17 2024-03-29 12:10:42.999958333+00:00       0.999958
# 18 2024-03-29 13:04:42.999958333+00:00       0.999958
# 19 2024-03-29 13:58:42.999958333+00:00       0.999958
# 20 2024-03-29 14:52:42.999958333+00:00       0.999958
# 21 2024-03-29 15:46:42.999958333+00:00       0.999958
# 22 2024-03-29 16:40:42.999958333+00:00       0.999958
# 23 2024-03-29 14:39:04.993333333+00:00  175679.993333

# %% [markdown]
# ## Create Processing Objects
#
# There are a few unique things with this data set that we need to take into account when processing.
#
# 1. The remote only has data for 150 samples/second and not 24k, therefore we need to account for that in the `KernelDataset`
# 2. These data use a different nomenclature than the default.  Instead of ["ex", "ey", "hx", "hy", "hz"] the data uses ["e1", "e2", "h1", "h2", "h3"].  We can change this in the `Config` object.
#
# Internally in `AuroraProcessing` the windowing parameters are adjusted based on the sample rate, but we will demonstrate how you might change the windowing and any other parameters in the decimations of the `Config` object.

# %% [markdown]
# ### 24k Hz Data

# %%
ap._remote_station_id = None
kds_24k = ap.create_kernel_dataset(
    local_station_id="9043",
    remote_station_id=None,
    sample_rate=24000
    )
window_size = 1024
window_overlap = 512

config_24k = ap.create_config(
        kds_24k,
        emtf_band_file=band_file_24k,
        num_samples_window=window_size)
config_24k.channel_nomenclature.ex = "e1"
config_24k.channel_nomenclature.ey = "e2"
config_24k.channel_nomenclature.hx = "h1"
config_24k.channel_nomenclature.hy = "h2"
config_24k.channel_nomenclature.hz = "h3"

for decimation in config_24k.decimations:
        # because we are only using a local station need to use the RME estimator.
        decimation.estimator.engine = "RME"
        decimation.window.type = "dpss"
        decimation.window.additional_args = {"alpha": 2.5}
        decimation.output_channels = ["e1", "e2", "h3"]
        decimation.input_channels = ["h1", "h2"]
        decimation.reference_channels = ["h1", "h2"]

        # here is where you would change windowing parameters
        decimation.window.overlap = window_overlap
        decimation.window.num_samples = window_size

        # Save Fourier Coefficents
        decimation.save_fcs = True
        decimation.save_fcs_type = "h5"
# Out:
# 2024-11-08T14:18:30.694848-0800 | INFO | mtpy.processing.kernel_dataset | _add_columns | KernelDataset DataFrame needs column fc, adding and setting dtype to <class 'pandas._libs.missing.NAType'>.
# 2024-11-08T14:18:30.698857-0800 | INFO | mtpy.processing.kernel_dataset | _add_columns | KernelDataset DataFrame needs column remote, adding and setting dtype to <class 'bool'>.
# 2024-11-08T14:18:30.702847-0800 | INFO | mtpy.processing.kernel_dataset | _add_columns | KernelDataset DataFrame needs column run_dataarray, adding and setting dtype to <class 'NoneType'>.
# 2024-11-08T14:18:30.705845-0800 | INFO | mtpy.processing.kernel_dataset | _add_columns | KernelDataset DataFrame needs column stft, adding and setting dtype to <class 'NoneType'>.
# 2024-11-08T14:18:30.707844-0800 | INFO | mtpy.processing.kernel_dataset | _add_columns | KernelDataset DataFrame needs column mth5_obj, adding and setting dtype to <class 'NoneType'>.

# %% [markdown]
# ### 150 Hz Data

# %%
kds_150 = ap.create_kernel_dataset(
    local_station_id="9043",
    remote_station_id="1003",
    sample_rate=150
    )

config_150 = ap.create_config(kds_150, emtf_band_file=band_file)
config_150.channel_nomenclature.ex = "e1"
config_150.channel_nomenclature.ey = "e2"
config_150.channel_nomenclature.hx = "h1"
config_150.channel_nomenclature.hy = "h2"
config_150.channel_nomenclature.hz = "h3"

for decimation in config_150.decimations:
        decimation.window.type = "dpss"
        decimation.window.additional_args = {"alpha": 2.5}
        decimation.output_channels = ["e1", "e2", "h3"]
        decimation.input_channels = ["h1", "h2"]
        decimation.reference_channels = ["h1", "h2"]

        # here is where you would change windowing parameters
        # decimation.window.overlap = 64
        # decimation.window.num_samples = 128
        
        # Save Fourier Coefficents
        decimation.save_fcs = True
        decimation.save_fcs_type = "h5"
# Out:
# 2024-11-08T14:18:31.063962-0800 | INFO | mtpy.processing.kernel_dataset | _add_columns | KernelDataset DataFrame needs column fc, adding and setting dtype to <class 'pandas._libs.missing.NAType'>.
# 2024-11-08T14:18:31.063962-0800 | INFO | mtpy.processing.kernel_dataset | _add_columns | KernelDataset DataFrame needs column remote, adding and setting dtype to <class 'bool'>.
# 2024-11-08T14:18:31.079992-0800 | INFO | mtpy.processing.kernel_dataset | _add_columns | KernelDataset DataFrame needs column run_dataarray, adding and setting dtype to <class 'NoneType'>.
# 2024-11-08T14:18:31.083357-0800 | INFO | mtpy.processing.kernel_dataset | _add_columns | KernelDataset DataFrame needs column stft, adding and setting dtype to <class 'NoneType'>.
# 2024-11-08T14:18:31.083357-0800 | INFO | mtpy.processing.kernel_dataset | _add_columns | KernelDataset DataFrame needs column mth5_obj, adding and setting dtype to <class 'NoneType'>.

# %% [markdown]
# #### Pick Runs
#
# With the short bursts, we probably don't want to process every single one, because there is a lot of redundant information.  We can chose from the `KernelDataset.df` object, which is a Pandas dataframe that tells Aurora which runs to process.  Therefore, you can query the dataframe as you like.  Here we can pick every second burst.

# %%
kds_24k.df = kds_24k.df.iloc[range(0, 20, 2)]

# %%
kds_24k.df
# Out:
#                                 channel_scale_factors  duration  \
# 0   {'e1': 1.0, 'e2': 1.0, 'h1': 1.0, 'h2': 1.0, '...  0.999958
# 2   {'e1': 1.0, 'e2': 1.0, 'h1': 1.0, 'h2': 1.0, '...  0.999958
# 4   {'e1': 1.0, 'e2': 1.0, 'h1': 1.0, 'h2': 1.0, '...  0.999958
# 6   {'e1': 1.0, 'e2': 1.0, 'h1': 1.0, 'h2': 1.0, '...  0.999958
# 8   {'e1': 1.0, 'e2': 1.0, 'h1': 1.0, 'h2': 1.0, '...  0.999958
# 10  {'e1': 1.0, 'e2': 1.0, 'h1': 1.0, 'h2': 1.0, '...  0.999958
# 12  {'e1': 1.0, 'e2': 1.0, 'h1': 1.0, 'h2': 1.0, '...  0.999958
# 14  {'e1': 1.0, 'e2': 1.0, 'h1': 1.0, 'h2': 1.0, '...  0.999958
# 16  {'e1': 1.0, 'e2': 1.0, 'h1': 1.0, 'h2': 1.0, '...  0.999958
# 18  {'e1': 1.0, 'e2': 1.0, 'h1': 1.0, 'h2': 1.0, '...  0.999958
#
#                                    end  has_data input_channels  \
# 0  2024-03-28 21:46:42.999958333+00:00      True       [h1, h2]
# 2  2024-03-28 23:34:42.999958333+00:00      True       [h1, h2]
# 4  2024-03-29 01:22:42.999958333+00:00      True       [h1, h2]
# 6  2024-03-29 03:10:42.999958333+00:00      True       [h1, h2]
# 8  2024-03-29 04:58:42.999958333+00:00      True       [h1, h2]
# 10 2024-03-29 06:46:42.999958333+00:00      True       [h1, h2]
# 12 2024-03-29 08:34:42.999958333+00:00      True       [h1, h2]
# 14 2024-03-29 10:22:42.999958333+00:00      True       [h1, h2]
# 16 2024-03-29 12:10:42.999958333+00:00      True       [h1, h2]
# 18 2024-03-29 13:58:42.999958333+00:00      True       [h1, h2]
#
#                                             mth5_path  n_samples  \
# 0   c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...      24000
# 2   c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...      24000
# 4   c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...      24000
# 6   c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...      24000
# 8   c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...      24000
# 10  c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...      24000
# 12  c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...      24000
# 14  c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...      24000
# 16  c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...      24000
# 18  c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...      24000
#
#    output_channels         run  sample_rate                     start station  \
# 0     [e1, e2, h3]  sr24k_0001      24000.0 2024-03-28 21:46:42+00:00    9043
# 2     [e1, e2, h3]  sr24k_0003      24000.0 2024-03-28 23:34:42+00:00    9043
# 4     [e1, e2, h3]  sr24k_0005      24000.0 2024-03-29 01:22:42+00:00    9043
# 6     [e1, e2, h3]  sr24k_0007      24000.0 2024-03-29 03:10:42+00:00    9043
# 8     [e1, e2, h3]  sr24k_0009      24000.0 2024-03-29 04:58:42+00:00    9043
# 10    [e1, e2, h3]  sr24k_0011      24000.0 2024-03-29 06:46:42+00:00    9043
# 12    [e1, e2, h3]  sr24k_0013      24000.0 2024-03-29 08:34:42+00:00    9043
# 14    [e1, e2, h3]  sr24k_0015      24000.0 2024-03-29 10:22:42+00:00    9043
# 16    [e1, e2, h3]  sr24k_0017      24000.0 2024-03-29 12:10:42+00:00    9043
# 18    [e1, e2, h3]  sr24k_0019      24000.0 2024-03-29 13:58:42+00:00    9043
#
#    survey       run_hdf5_reference   station_hdf5_reference    fc  remote  \
# 0    MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False
# 2    MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False
# 4    MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False
# 6    MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False
# 8    MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False
# 10   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False
# 12   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False
# 14   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False
# 16   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False
# 18   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False
#
#    run_dataarray  stft mth5_obj
# 0           None  None     None
# 2           None  None     None
# 4           None  None     None
# 6           None  None     None
# 8           None  None     None
# 10          None  None     None
# 12          None  None     None
# 14          None  None     None
# 16          None  None     None
# 18          None  None     None

# %% [markdown]
# #### Set Run Times
# We could also set the start and end time for each run if we wanted. There is a convenience method `KernelDataset.set_run_times` where you just need to input a dictionary keyed by the run name and then have a start and end time.
#
# For example an input dictionary could be:
#
# ```python
# run_times_dict = {
#     "sr150_0001": {"start":"2024-03-28 14:46:00+00:00", "end":"2024-03-29 10:00:00+00:00"},
#     }
# ```

# %%
kds_150.df
# Out:
#                                channel_scale_factors      duration  \
# 0  {'e1': 1.0, 'e2': 1.0, 'h1': 1.0, 'h2': 1.0, '...  69521.993333
# 1                             {'h1': 1.0, 'h2': 1.0}  69521.993333
#
#                                   end  has_data input_channels  \
# 0 2024-03-29 10:04:39.993333333+00:00      True       [h1, h2]
# 1 2024-03-29 10:04:39.993333333+00:00      True       [h1, h2]
#
#                                            mth5_path  n_samples  \
# 0  c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...   10428300
# 1  c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...   26352000
#
#   output_channels         run  sample_rate                     start station  \
# 0    [e1, e2, h3]  sr150_0001        150.0 2024-03-28 14:45:58+00:00    9043
# 1              []  sr150_0001        150.0 2024-03-28 14:45:58+00:00    1003
#
#   survey       run_hdf5_reference   station_hdf5_reference    fc  remote  \
# 0   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False
# 1   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>    True
#
#   run_dataarray  stft mth5_obj
# 0          None  None     None
# 1          None  None     None

# %%
run_times_dict = {
    "sr150_0001": {"start":"2024-03-28 14:46:00+00:00", "end":"2024-03-29 10:00:00+00:00"},
    }
kds_150.set_run_times(run_times_dict)

# %%
kds_150.df
# Out:
#                                channel_scale_factors  duration  \
# 0  {'e1': 1.0, 'e2': 1.0, 'h1': 1.0, 'h2': 1.0, '...   69240.0
# 1                             {'h1': 1.0, 'h2': 1.0}   69240.0
#
#                         end  has_data input_channels  \
# 0 2024-03-29 10:00:00+00:00      True       [h1, h2]
# 1 2024-03-29 10:00:00+00:00      True       [h1, h2]
#
#                                            mth5_path  n_samples  \
# 0  c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...   10428300
# 1  c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_c...   26352000
#
#   output_channels         run  sample_rate                     start station  \
# 0    [e1, e2, h3]  sr150_0001        150.0 2024-03-28 14:46:00+00:00    9043
# 1              []  sr150_0001        150.0 2024-03-28 14:46:00+00:00    1003
#
#   survey       run_hdf5_reference   station_hdf5_reference    fc  remote  \
# 0   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False
# 1   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>    True
#
#   run_dataarray  stft mth5_obj
# 0          None  None     None
# 1          None  None     None

# %% [markdown]
# ### Create Processing Dictionary
#
# Now that we have created unique objects for each sample rate, we need to aggregate these into a dictionary that can be input into `AuroraProcessing`

# %%
processing_dict = {
    150: {"config": config_150, "kernel_dataset": kds_150},
    24000: {"config": config_24k, "kernel_dataset": kds_24k}
    }

# %% [markdown]
# ## Process Data
# This will the various sample rates, create a transfer function for each and then merge them according to the `merge_dict`.

# %%
tf_processed = ap.process(processing_dict=processing_dict)
# Out:
# 2024-11-08T14:18:32.152567-0800 | INFO | aurora.pipelines.transfer_function_kernel | show_processing_summary | Processing Summary Dataframe:
# 2024-11-08T14:18:32.197929-0800 | INFO | aurora.pipelines.transfer_function_kernel | show_processing_summary |
#     duration  has_data  n_samples         run station survey       run_hdf5_reference   station_hdf5_reference    fc  remote  stft mth5_obj dec_level  dec_factor  sample_rate  window_duration  num_samples_window  num_samples  num_stft_windows
# 0    69240.0      True   26352000  sr150_0001    1003   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>    True  None     None         0         1.0   150.000000         0.853333                 128   10386000.0          162280.0
# 1    69240.0      True   26352000  sr150_0001    1003   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>    True  None     None         1         4.0    37.500000         3.413333                 128    2596500.0           40569.0
# 2    69240.0      True   26352000  sr150_0001    1003   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>    True  None     None         2         4.0     9.375000        13.653333                 128     649125.0           10141.0
# 3    69240.0      True   26352000  sr150_0001    1003   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>    True  None     None         3         4.0     2.343750        54.613333                 128     162281.0            2534.0
# 4    69240.0      True   26352000  sr150_0001    1003   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>    True  None     None         4         4.0     0.585938       218.453333                 128      40570.0             632.0
# 5    69240.0      True   26352000  sr150_0001    1003   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>    True  None     None         5         4.0     0.146484       873.813333                 128      10142.0             157.0
# 6    69240.0      True   26352000  sr150_0001    1003   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>    True  None     None         6         4.0     0.036621      3495.253333                 128       2535.0              38.0
# 7    69240.0      True   26352000  sr150_0001    1003   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>    True  None     None         7         4.0     0.009155     13981.013333                 128        633.0               8.0
# 8    69240.0      True   26352000  sr150_0001    1003   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>    True  None     None         8         4.0     0.002289     55924.053333                 128        158.0               1.0
# 9    69240.0      True   10428300  sr150_0001    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         0         1.0   150.000000         0.853333                 128   10386000.0          162280.0
# 10   69240.0      True   10428300  sr150_0001    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         1         4.0    37.500000         3.413333                 128    2596500.0           40569.0
# 11   69240.0      True   10428300  sr150_0001    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         2         4.0     9.375000        13.653333                 128     649125.0           10141.0
# 12   69240.0      True   10428300  sr150_0001    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         3         4.0     2.343750        54.613333                 128     162281.0            2534.0
# 13   69240.0      True   10428300  sr150_0001    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         4         4.0     0.585938       218.453333                 128      40570.0             632.0
# 14   69240.0      True   10428300  sr150_0001    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         5         4.0     0.146484       873.813333                 128      10142.0             157.0
# 15   69240.0      True   10428300  sr150_0001    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         6         4.0     0.036621      3495.253333                 128       2535.0              38.0
# 16   69240.0      True   10428300  sr150_0001    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         7         4.0     0.009155     13981.013333                 128        633.0               8.0
# 17   69240.0      True   10428300  sr150_0001    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         8         4.0     0.002289     55924.053333                 128        158.0               1.0
# 2024-11-08T14:18:32.223605-0800 | INFO | aurora.pipelines.transfer_function_kernel | memory_check | Total memory: 15.88 GB
# 2024-11-08T14:18:32.225602-0800 | INFO | aurora.pipelines.transfer_function_kernel | memory_check | Total Bytes of Raw Data: 0.155 GB
# 2024-11-08T14:18:32.228204-0800 | INFO | aurora.pipelines.transfer_function_kernel | memory_check | Raw Data will use: 0.975 % of memory
# 2024-11-08T14:18:32.319488-0800 | INFO | aurora.pipelines.transfer_function_kernel | mth5_has_fcs | Fourier coefficients not detected for survey: MIST, station: 1003, run: sr150_0001-- Fourier coefficients will be computed
# 2024-11-08T14:18:32.321489-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_1003.h5
# 2024-11-08T14:18:32.731471-0800 | INFO | aurora.pipelines.transfer_function_kernel | mth5_has_fcs | Fourier coefficients not detected for survey: MIST, station: 9043, run: sr150_0001-- Fourier coefficients will be computed
# 2024-11-08T14:18:32.731471-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:18:32.731471-0800 | INFO | aurora.pipelines.transfer_function_kernel | check_if_fcs_already_exist | FC levels not present
# 2024-11-08T14:18:32.731471-0800 | WARNING | aurora.pipelines.transfer_function_kernel | validate_save_fc_settings |
#  Saving FCs for remote reference processing is not supported
#  - To save FCs, process as single station, then you can use the FCs for RR processing
#  - See issue #319 for details
#  - forcing processing config save_fcs = False
# 2024-11-08T14:18:32.764807-0800 | INFO | aurora.pipelines.process_mth5 | process_mth5_legacy | Processing config indicates 9 decimation levels
# 2024-11-08T14:18:32.764807-0800 | INFO | aurora.pipelines.transfer_function_kernel | valid_decimations | After validation there are 8 valid decimation levels
# 2024-11-08T14:18:38.729148-0800 | WARNING | mth5.timeseries.run_ts | validate_metadata | start time of dataset 2024-03-28T14:46:00+00:00 does not match metadata start 2024-03-28T14:45:58+00:00 updating metatdata value to 2024-03-28T14:46:00+00:00
# 2024-11-08T14:18:38.746584-0800 | WARNING | mth5.timeseries.run_ts | validate_metadata | end time of dataset 2024-03-29T10:00:00+00:00 does not match metadata end 2024-03-29T10:04:39.993333333+00:00 updating metatdata value to 2024-03-29T10:00:00+00:00
# 2024-11-08T14:18:43.801155-0800 | WARNING | mth5.timeseries.run_ts | validate_metadata | start time of dataset 2024-03-28T14:46:00+00:00 does not match metadata start 2024-03-27T13:51:05+00:00 updating metatdata value to 2024-03-28T14:46:00+00:00
# 2024-11-08T14:18:43.805160-0800 | WARNING | mth5.timeseries.run_ts | validate_metadata | end time of dataset 2024-03-29T10:00:00+00:00 does not match metadata end 2024-03-29T14:39:04.993333333+00:00 updating metatdata value to 2024-03-29T10:00:00+00:00
# 2024-11-08T14:18:44.468445-0800 | INFO | mtpy.processing.kernel_dataset | initialize_dataframe_for_processing | Dataset dataframe initialized successfully
# 2024-11-08T14:18:44.487039-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | Dataset Dataframe Updated for decimation level 0 Successfully
# 2024-11-08T14:19:28.163310-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:19:39.085924-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:19:39.574142-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.171526s  (5.830005Hz)
# 2024-11-08T14:19:43.613772-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.132864s  (7.526503Hz)
# 2024-11-08T14:19:48.219203-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.101094s  (9.891763Hz)
# 2024-11-08T14:19:53.503414-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.078307s  (12.770212Hz)
# 2024-11-08T14:20:01.054250-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.059419s  (16.829773Hz)
# 2024-11-08T14:20:09.717285-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.043004s  (23.253674Hz)
# 2024-11-08T14:20:20.641895-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | DECIMATION LEVEL 1
# 2024-11-08T14:20:23.759537-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | Dataset Dataframe Updated for decimation level 1 Successfully
# 2024-11-08T14:20:30.336845-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:20:32.953196-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:20:33.275983-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.686106s  (1.457501Hz)
# 2024-11-08T14:20:33.984006-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.570875s  (1.751698Hz)
# 2024-11-08T14:20:34.732695-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.459211s  (2.177647Hz)
# 2024-11-08T14:20:36.117219-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.361306s  (2.767741Hz)
# 2024-11-08T14:20:37.497501-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.286693s  (3.488051Hz)
# 2024-11-08T14:20:39.225639-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.222071s  (4.503055Hz)
# 2024-11-08T14:20:42.556212-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | DECIMATION LEVEL 2
# 2024-11-08T14:20:43.436309-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | Dataset Dataframe Updated for decimation level 2 Successfully
# 2024-11-08T14:20:45.271558-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:20:46.097935-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:20:46.203998-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 2.744423s  (0.364375Hz)
# 2024-11-08T14:20:46.667855-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 2.283498s  (0.437925Hz)
# 2024-11-08T14:20:47.156254-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 1.836845s  (0.544412Hz)
# 2024-11-08T14:20:47.733819-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 1.445222s  (0.691935Hz)
# 2024-11-08T14:20:48.283071-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 1.146772s  (0.872013Hz)
# 2024-11-08T14:20:48.890566-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.888286s  (1.125764Hz)
# 2024-11-08T14:20:50.403473-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | DECIMATION LEVEL 3
# 2024-11-08T14:20:50.636111-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | Dataset Dataframe Updated for decimation level 3 Successfully
# 2024-11-08T14:20:51.976299-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:20:52.549225-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:20:52.605444-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 10.098009s  (0.099029Hz)
# 2024-11-08T14:20:52.897598-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 6.949926s  (0.143886Hz)
# 2024-11-08T14:20:53.247649-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 4.822475s  (0.207362Hz)
# 2024-11-08T14:20:53.697410-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 3.553144s  (0.281441Hz)
# 2024-11-08T14:20:54.110979-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 2.752253s  (0.363339Hz)
# 2024-11-08T14:20:55.256514-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | DECIMATION LEVEL 4
# 2024-11-08T14:20:55.329986-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | Dataset Dataframe Updated for decimation level 4 Successfully
# 2024-11-08T14:20:55.996595-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:20:56.268155-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:20:56.289179-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 40.392036s  (0.024757Hz)
# 2024-11-08T14:20:56.513005-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 27.799705s  (0.035972Hz)
# 2024-11-08T14:20:56.765639-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 19.289901s  (0.051841Hz)
# 2024-11-08T14:20:57.138735-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 14.212575s  (0.070360Hz)
# 2024-11-08T14:20:57.549485-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 11.009013s  (0.090835Hz)
# 2024-11-08T14:20:58.876989-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | DECIMATION LEVEL 5
# 2024-11-08T14:20:58.928222-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | Dataset Dataframe Updated for decimation level 5 Successfully
# 2024-11-08T14:21:00.230368-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:21:00.630582-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:21:00.645051-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 161.568142s  (0.006189Hz)
# 2024-11-08T14:21:00.894765-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 111.198822s  (0.008993Hz)
# 2024-11-08T14:21:01.232647-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 77.159602s  (0.012960Hz)
# 2024-11-08T14:21:01.522829-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 56.850300s  (0.017590Hz)
# 2024-11-08T14:21:01.794540-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 44.036053s  (0.022709Hz)
# 2024-11-08T14:21:02.655523-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | DECIMATION LEVEL 6
# 2024-11-08T14:21:02.678616-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | Dataset Dataframe Updated for decimation level 6 Successfully
# 2024-11-08T14:21:03.196849-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:21:03.393958-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:21:03.410595-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 646.272570s  (0.001547Hz)
# 2024-11-08T14:21:03.593879-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 444.795288s  (0.002248Hz)
# 2024-11-08T14:21:03.762278-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 308.638409s  (0.003240Hz)
# 2024-11-08T14:21:03.943732-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 227.401199s  (0.004398Hz)
# 2024-11-08T14:21:04.155039-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 176.144211s  (0.005677Hz)
# 2024-11-08T14:21:04.910142-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | DECIMATION LEVEL 7
# 2024-11-08T14:21:04.932477-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | Dataset Dataframe Updated for decimation level 7 Successfully
# 2024-11-08T14:21:05.442743-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:21:05.676518-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Skip saving FCs. dec_level_config.save_fc =  False
# 2024-11-08T14:21:05.693133-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 2585.090280s  (0.000387Hz)
# 2024-11-08T14:21:05.893160-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 1779.181151s  (0.000562Hz)
# 2024-11-08T14:21:06.109700-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 1234.553636s  (0.000810Hz)
# 2024-11-08T14:21:06.289379-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 909.604795s  (0.001099Hz)
# 2024-11-08T14:21:06.459527-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 704.576845s  (0.001419Hz)
# 2024-11-08T14:21:07.177628-0800 | WARNING | aurora.pipelines.transfer_function_kernel | make_decimation_dict_for_tf | Possibly invalid decimation level
# 2024-11-08T14:21:07.177628-0800 | WARNING | aurora.pipelines.transfer_function_kernel | make_decimation_dict_for_tf | Possibly invalid decimation level
# 2024-11-08T14:21:07.177628-0800 | WARNING | aurora.pipelines.transfer_function_kernel | make_decimation_dict_for_tf | Possibly invalid decimation level
# 2024-11-08T14:21:07.177628-0800 | WARNING | aurora.pipelines.transfer_function_kernel | make_decimation_dict_for_tf | Possibly invalid decimation level
# 2024-11-08T14:21:07.177628-0800 | WARNING | aurora.pipelines.transfer_function_kernel | make_decimation_dict_for_tf | Possibly invalid decimation level
# 2024-11-08T14:21:07.642647-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:21:07.659302-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_1003.h5
# 2024-11-08T14:21:07.876544-0800 | INFO | aurora.pipelines.transfer_function_kernel | show_processing_summary | Processing Summary Dataframe:
# 2024-11-08T14:21:07.896602-0800 | INFO | aurora.pipelines.transfer_function_kernel | show_processing_summary |
#     duration  has_data  n_samples         run station survey       run_hdf5_reference   station_hdf5_reference    fc  remote  stft mth5_obj dec_level  dec_factor  sample_rate  window_duration  num_samples_window  num_samples  num_stft_windows
# 0   0.999958      True      24000  sr24k_0001    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         0         1.0      24000.0         0.042667                1024      23998.0              45.0
# 1   0.999958      True      24000  sr24k_0001    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         1         4.0       6000.0         0.170667                1024       5999.0              10.0
# 2   0.999958      True      24000  sr24k_0001    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         2         4.0       1500.0         0.682667                1024       1499.0               1.0
# 3   0.999958      True      24000  sr24k_0003    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         0         1.0      24000.0         0.042667                1024      23998.0              45.0
# 4   0.999958      True      24000  sr24k_0003    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         1         4.0       6000.0         0.170667                1024       5999.0              10.0
# 5   0.999958      True      24000  sr24k_0003    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         2         4.0       1500.0         0.682667                1024       1499.0               1.0
# 6   0.999958      True      24000  sr24k_0005    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         0         1.0      24000.0         0.042667                1024      23998.0              45.0
# 7   0.999958      True      24000  sr24k_0005    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         1         4.0       6000.0         0.170667                1024       5999.0              10.0
# 8   0.999958      True      24000  sr24k_0005    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         2         4.0       1500.0         0.682667                1024       1499.0               1.0
# 9   0.999958      True      24000  sr24k_0007    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         0         1.0      24000.0         0.042667                1024      23998.0              45.0
# 10  0.999958      True      24000  sr24k_0007    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         1         4.0       6000.0         0.170667                1024       5999.0              10.0
# 11  0.999958      True      24000  sr24k_0007    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         2         4.0       1500.0         0.682667                1024       1499.0               1.0
# 12  0.999958      True      24000  sr24k_0009    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         0         1.0      24000.0         0.042667                1024      23998.0              45.0
# 13  0.999958      True      24000  sr24k_0009    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         1         4.0       6000.0         0.170667                1024       5999.0              10.0
# 14  0.999958      True      24000  sr24k_0009    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         2         4.0       1500.0         0.682667                1024       1499.0               1.0
# 15  0.999958      True      24000  sr24k_0011    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         0         1.0      24000.0         0.042667                1024      23998.0              45.0
# 16  0.999958      True      24000  sr24k_0011    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         1         4.0       6000.0         0.170667                1024       5999.0              10.0
# 17  0.999958      True      24000  sr24k_0011    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         2         4.0       1500.0         0.682667                1024       1499.0               1.0
# 18  0.999958      True      24000  sr24k_0013    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         0         1.0      24000.0         0.042667                1024      23998.0              45.0
# 19  0.999958      True      24000  sr24k_0013    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         1         4.0       6000.0         0.170667                1024       5999.0              10.0
# 20  0.999958      True      24000  sr24k_0013    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         2         4.0       1500.0         0.682667                1024       1499.0               1.0
# 21  0.999958      True      24000  sr24k_0015    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         0         1.0      24000.0         0.042667                1024      23998.0              45.0
# 22  0.999958      True      24000  sr24k_0015    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         1         4.0       6000.0         0.170667                1024       5999.0              10.0
# 23  0.999958      True      24000  sr24k_0015    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         2         4.0       1500.0         0.682667                1024       1499.0               1.0
# 24  0.999958      True      24000  sr24k_0017    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         0         1.0      24000.0         0.042667                1024      23998.0              45.0
# 25  0.999958      True      24000  sr24k_0017    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         1         4.0       6000.0         0.170667                1024       5999.0              10.0
# 26  0.999958      True      24000  sr24k_0017    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         2         4.0       1500.0         0.682667                1024       1499.0               1.0
# 27  0.999958      True      24000  sr24k_0019    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         0         1.0      24000.0         0.042667                1024      23998.0              45.0
# 28  0.999958      True      24000  sr24k_0019    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         1         4.0       6000.0         0.170667                1024       5999.0              10.0
# 29  0.999958      True      24000  sr24k_0019    9043   MIST  <HDF5 object reference>  <HDF5 object reference>  <NA>   False  None     None         2         4.0       1500.0         0.682667                1024       1499.0               1.0
# 2024-11-08T14:21:07.904598-0800 | INFO | aurora.pipelines.transfer_function_kernel | memory_check | Total memory: 15.88 GB
# 2024-11-08T14:21:07.906600-0800 | INFO | aurora.pipelines.transfer_function_kernel | memory_check | Total Bytes of Raw Data: 0.002 GB
# 2024-11-08T14:21:07.907600-0800 | INFO | aurora.pipelines.transfer_function_kernel | memory_check | Raw Data will use: 0.011 % of memory
# 2024-11-08T14:21:08.009247-0800 | INFO | aurora.pipelines.transfer_function_kernel | mth5_has_fcs | Fourier coefficients not detected for survey: MIST, station: 9043, run: sr24k_0001-- Fourier coefficients will be computed
# 2024-11-08T14:21:08.024259-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:21:08.109012-0800 | INFO | aurora.pipelines.transfer_function_kernel | mth5_has_fcs | Fourier coefficients not detected for survey: MIST, station: 9043, run: sr24k_0003-- Fourier coefficients will be computed
# 2024-11-08T14:21:08.109012-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:21:08.225811-0800 | INFO | aurora.pipelines.transfer_function_kernel | mth5_has_fcs | Fourier coefficients not detected for survey: MIST, station: 9043, run: sr24k_0005-- Fourier coefficients will be computed
# 2024-11-08T14:21:08.225811-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:21:08.340817-0800 | INFO | aurora.pipelines.transfer_function_kernel | mth5_has_fcs | Fourier coefficients not detected for survey: MIST, station: 9043, run: sr24k_0007-- Fourier coefficients will be computed
# 2024-11-08T14:21:08.340817-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:21:08.478034-0800 | INFO | aurora.pipelines.transfer_function_kernel | mth5_has_fcs | Fourier coefficients not detected for survey: MIST, station: 9043, run: sr24k_0009-- Fourier coefficients will be computed
# 2024-11-08T14:21:08.479033-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:21:08.575762-0800 | INFO | aurora.pipelines.transfer_function_kernel | mth5_has_fcs | Fourier coefficients not detected for survey: MIST, station: 9043, run: sr24k_0011-- Fourier coefficients will be computed
# 2024-11-08T14:21:08.575762-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:21:08.727358-0800 | INFO | aurora.pipelines.transfer_function_kernel | mth5_has_fcs | Fourier coefficients not detected for survey: MIST, station: 9043, run: sr24k_0013-- Fourier coefficients will be computed
# 2024-11-08T14:21:08.727358-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:21:08.843223-0800 | INFO | aurora.pipelines.transfer_function_kernel | mth5_has_fcs | Fourier coefficients not detected for survey: MIST, station: 9043, run: sr24k_0015-- Fourier coefficients will be computed
# 2024-11-08T14:21:08.858208-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:21:08.992644-0800 | INFO | aurora.pipelines.transfer_function_kernel | mth5_has_fcs | Fourier coefficients not detected for survey: MIST, station: 9043, run: sr24k_0017-- Fourier coefficients will be computed
# 2024-11-08T14:21:08.995644-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:21:09.153071-0800 | INFO | aurora.pipelines.transfer_function_kernel | mth5_has_fcs | Fourier coefficients not detected for survey: MIST, station: 9043, run: sr24k_0019-- Fourier coefficients will be computed
# 2024-11-08T14:21:09.155068-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:21:09.161216-0800 | INFO | aurora.pipelines.transfer_function_kernel | check_if_fcs_already_exist | FC levels not present
# 2024-11-08T14:21:09.167792-0800 | INFO | aurora.pipelines.process_mth5 | process_mth5_legacy | Processing config indicates 3 decimation levels
# 2024-11-08T14:21:09.170787-0800 | INFO | aurora.pipelines.transfer_function_kernel | valid_decimations | After validation there are 2 valid decimation levels
# 2024-11-08T14:21:21.581154-0800 | INFO | mtpy.processing.kernel_dataset | initialize_dataframe_for_processing | Dataset dataframe initialized successfully
# 2024-11-08T14:21:21.590563-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | Dataset Dataframe Updated for decimation level 0 Successfully
# 2024-11-08T14:21:22.396876-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:22.506021-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:22.587181-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:22.587181-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:22.671584-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:22.671584-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:22.778076-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:22.782075-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:22.787073-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:23.732055-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:23.929296-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:24.115865-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:24.121375-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:24.305207-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:24.310221-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:24.498420-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:24.501484-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:24.506511-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:25.815281-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:25.988453-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:26.064301-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:26.064301-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:26.145350-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:26.147414-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:26.213389-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:26.213389-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:26.213389-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:27.038585-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:27.132672-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:27.237281-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:27.237281-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:27.356989-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:27.356989-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:27.459672-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:27.462673-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:27.466674-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:28.432300-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:28.503660-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:28.589677-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:28.591197-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:28.659593-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:28.659593-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:28.740106-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:28.740106-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:28.740106-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:29.553727-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:29.625155-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:29.704682-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:29.707679-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:29.769337-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:29.769337-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:29.847485-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:29.860505-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:29.863516-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:30.566298-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:30.613220-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:30.681034-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:30.683027-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:30.736141-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:30.738116-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:30.780994-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:30.780994-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:30.780994-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:31.327750-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:31.390779-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:31.453318-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:31.453318-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:31.516238-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:31.516238-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:31.579134-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:31.579134-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:31.579134-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:32.216396-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:32.286982-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:32.330157-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:32.330157-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:32.394819-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:32.410440-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:32.520253-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:32.520253-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:32.535873-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:33.132497-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:33.199539-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:33.266564-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:33.266564-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:33.331492-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:33.333858-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:33.390325-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:33.392294-0800 | WARNING | mt_metadata.timeseries.filters.frequency_response_table_filter | complex_response | Extrapolating frequencies larger (11976.5625 Hz) than table frequencies (10240.0 Hz).
# 2024-11-08T14:21:33.395298-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:33.653888-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.001561s  (640.684544Hz)
# 2024-11-08T14:21:33.818960-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.001077s  (928.595406Hz)
# 2024-11-08T14:21:33.994838-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.000780s  (1282.600993Hz)
# 2024-11-08T14:21:34.167649-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.000611s  (1635.552986Hz)
# 2024-11-08T14:21:34.396251-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.000490s  (2042.191834Hz)
# 2024-11-08T14:21:34.641469-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.000398s  (2512.544819Hz)
# 2024-11-08T14:21:34.869455-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.000329s  (3036.920337Hz)
# 2024-11-08T14:21:35.118247-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.000268s  (3732.362085Hz)
# 2024-11-08T14:21:35.439739-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.000219s  (4555.851521Hz)
# 2024-11-08T14:21:35.712055-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.000184s  (5432.863561Hz)
# 2024-11-08T14:21:37.073896-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | DECIMATION LEVEL 1
# 2024-11-08T14:21:37.259159-0800 | INFO | aurora.pipelines.transfer_function_kernel | update_dataset_df | Dataset Dataframe Updated for decimation level 1 Successfully
# 2024-11-08T14:21:37.792771-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:38.532719-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:39.374849-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:40.075561-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:40.876218-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:41.777314-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:42.477908-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:43.102889-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:43.851822-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:44.646652-0800 | INFO | aurora.pipelines.process_mth5 | save_fourier_coefficients | Saving FC level
# 2024-11-08T14:21:44.921844-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.038899s  (25.707903Hz)
# 2024-11-08T14:21:45.061147-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.023611s  (42.354001Hz)
# 2024-11-08T14:21:45.202969-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.015070s  (66.355967Hz)
# 2024-11-08T14:21:45.335763-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.010420s  (95.966832Hz)
# 2024-11-08T14:21:45.461266-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.007654s  (130.658807Hz)
# 2024-11-08T14:21:45.605654-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.005564s  (179.716688Hz)
# 2024-11-08T14:21:45.757389-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.003821s  (261.695064Hz)
# 2024-11-08T14:21:45.911232-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.002753s  (363.198548Hz)
# 2024-11-08T14:21:46.111778-0800 | INFO | aurora.time_series.frequency_band_helpers | get_band_for_tf_estimate | Processing band 0.002078s  (481.120342Hz)
# 2024-11-08T14:21:47.772838-0800 | WARNING | aurora.pipelines.transfer_function_kernel | make_decimation_dict_for_tf | Possibly invalid decimation level
# 2024-11-08T14:21:47.772838-0800 | WARNING | aurora.pipelines.transfer_function_kernel | make_decimation_dict_for_tf | Possibly invalid decimation level
# 2024-11-08T14:21:47.772838-0800 | WARNING | aurora.pipelines.transfer_function_kernel | make_decimation_dict_for_tf | Possibly invalid decimation level
# 2024-11-08T14:21:50.359281-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5
# 2024-11-08T14:21:52.552299-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\mt\mt_short_course\data\mth5\phx_9043.h5

# %% [markdown]
# ## Processed Data
#
# Now the data have processed and we can have a look at the results.
#
# First have a look at what the out put is.  It is a dictionary with keys as the sample rate and values as more dictionaries with information on if the sample rate was properly processed and if it was the transfer function as an `mtpy.MT` object.
#
# Notice that there are 3 entries in the dictionary with one for `"combined"` which is the combined transfer function of the various sample rates you processed.

# %%
tf_processed
# Out:
# {150: {'processed': True,
#   'tf': TF( survey='MIST', station='9043', latitude=33.05, longitude=-115.98, elevation=-47.76 )},
#  24000: {'processed': True,
#   'tf': TF( survey='MIST', station='9043', latitude=33.05, longitude=-115.98, elevation=-47.76 )},
#  'combined': {'processed': True,
#   'tf': TF( survey='MIST', station='9043', latitude=33.05, longitude=-115.98, elevation=-47.76 )}}

# %% [markdown]
# ### Plot The Combined Response
#
# Now lets plot the response. Including all 4 components and the induction vectors.

# %%
tf_processed["combined"]["tf"].plot_mt_response(plot_num=2)
# Out:
# Plotting PlotMTResponse

# %% [markdown]
# #### Uh-oh
#
# Looks like there was a flipped channel.  Which one do you think it was?
#
# We can flip the channel in the transfer function by using `flip_phase`.

# %%
tf_processed["combined"]["tf"].flip_phase(zyx=True, zyy=True, tzy=True, inplace=True)

# %%
tf_processed["combined"]["tf"].plot_mt_response(plot_num=2)
# Out:
# Plotting PlotMTResponse

# %% [markdown]
# ### Write to file
# By default `AuroraProcessing` will write the transfer functions to the station MTH5 file.  However, not everyone uses MTH5 yet and so you might want to write to a legacy format.  You can do that by using the `write` method of the transfer function object.

# %%
edi_obj = tf_processed["combined"]["tf"].write(edi_path.joinpath(f"{ap.local_station_id}_RR_{ap.remote_station_id}.edi"))

# %%
help(tf_processed["combined"]["tf"].write)
# Out:
# Help on method write in module mt_metadata.transfer_functions.core:
#
# write(fn=None, save_dir=None, fn_basename=None, file_type='edi', **kwargs) method of mtpy.core.mt.MT instance
#     Write an mt file, the supported file types are EDI and XML.
#
#     .. todo:: j-files and avg files
#
#     :param fn: full path to file to save to
#     :type fn: :class:`pathlib.Path` or string
#
#     :param save_dir: full path save directory
#     :type save_dir: string
#
#     :param fn_basename: name of file with or without extension
#     :type fn_basename: string
#
#     :param file_type: [ 'edi' | 'xml' | "zmm" ]
#     :type file_type: string
#
#     keyword arguments include
#
#     :param longitude_format:  whether to write longitude as longitude or LONG.
#                               options are 'longitude' or 'LONG', default 'longitude'
#     :type longitude_format:  string
#     :param latlon_format:  format of latitude and longitude in output edi,
#                            degrees minutes seconds ('dms') or decimal
#                            degrees ('dd')
#     :type latlon_format:  string
#
#     :returns: full path to file
#     :rtype: string
#
#     :Example: ::
#
#         >>> tf_obj.write(file_type='xml')
